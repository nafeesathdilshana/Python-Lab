# %%
class employee:
    def __init__(self,empid,name,designation,salary):
        self.empid=empid
        self.name=name
        self.designation=designation
        self.salary=salary
    def employeeDetails(self):
        print(self.empid,end="\t\t")
        print(self.name,end="\t\t")
        print(self.designation,end="\t\t")
        print(self.salary,end="\t\t")
        print(self.grosssal(),end="\t\t")
        print(self.netsal())
    def grosssal(self):
        DA=5/100*self.salary
        HRA=10/100*self.salary
        gross=self.salary+DA+HRA
        return gross
    def netsal(self):
        LIC=3/100*self.salary
        PF=8/100*self.salary
        deduction=LIC+PF
        netsalary=self.grosssal()-deduction
        return netsalary
empid=[]
name=[]
designation=[]
salary=[]
for i in range(5):
    empid.append(int(input("enter employee id:")))
    name.append(input("enter name:"))
    designation.append(input("enter employee designation:"))
    salary.append(float(input("enter basic salary:")))
emp1=employee(empid[0],name[0],designation[0],salary[0])
emp2=employee(empid[1],name[1],designation[1],salary[1])
emp3=employee(empid[2],name[2],designation[2],salary[2])
emp4=employee(empid[3],name[3],designation[3],salary[3])
emp5=employee(empid[4],name[4],designation[4],salary[4])
print("**************************Employee Details*****************************")
print("-----------------------------------------------------------------------")
print("Emp Id:",end="\t\t")
print("name:",end="\t\t")
print("designation:",end="\t\t")
print("salary:",end="\t\t")
print("grosssalary:",end="\t\t")
print("netsalary:")
print("-----------------------------------------------------------------------")
emp1.employeeDetails()
emp2.employeeDetails()
emp3.employeeDetails()
emp4.employeeDetails()
emp5.employeeDetails()
# Out:
# enter employee id:121
# enter name:hgggggggggggg
# enter employee designation:hhh
# enter basic salary:7888
# enter employee id:23
# enter name:iu
# enter employee designation:jj
# enter basic salary:600
# enter employee id:356
# enter name:gdggg
# enter employee designation:gdh
# enter basic salary:90078
# enter employee id:223
# enter name:rth
# enter employee designation:deff
# enter basic salary:7000
# enter employee id:20
# enter name:ghj
# enter employee designation:jgg
# enter basic salary:5000
# **************************Employee Details*****************************
# -----------------------------------------------------------------------
# Emp Id:		name:		designation:		salary:		grosssalary:		netsalary:
# -----------------------------------------------------------------------
# 121		hgggggggggggg		hhh		7888.0		9071.199999999999		8203.519999999999
# 23		iu		jj		600.0		690.0		624.0
# 356		gdggg		gdh		90078.0		103589.7		93681.12
# 223		rth		deff		7000.0		8050.0		7280.0
# 20		ghj		jgg		5000.0		5750.0		5200.0
